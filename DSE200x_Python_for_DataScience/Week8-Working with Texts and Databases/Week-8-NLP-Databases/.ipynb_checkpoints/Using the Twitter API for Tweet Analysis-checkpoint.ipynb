# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
        
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
#!pip install twitter

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x105a386d8>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2487889
#LOCAL_WOE_ID=725003

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': 'Ramos',
#     'url': 'http://twitter.com/search?q=Ramos',
#     'promoted_content': None,
#     'query': 'Ramos',
#     'tweet_volume': 205015},
#    {'name': '#ElClasico',
#     'url': 'http://twitter.com/search?q=%23ElClasico',
#     'promoted_content': None,
#     'query': '%23ElClasico',
#     'tweet_volume': 201267},
#    {'name': 'Rakitic',
#     'url': 'http://twitter.com/search?q=Rakitic',
#     'promoted_content': None,
#     'query': 'Rakitic',
#     'tweet_volume': 54841},
#    {'name': '#CePostaPerTe',
#     'url': 'http://twitter.com/search?q=%23CePostaPerTe',
#     'promoted_content': None,
#     'query': '%23CePostaPerTe',
#     'tweet_volume': 15725},
#    {'name': '#LaLigaxESPN',
#     'url': 'http://twitter.com/search?q=%23LaLigaxESPN',
#     'promoted_content': None,
#     'query': '%23LaLigaxESPN',
#     'tweet_volume': None},
#    {'name': '#برشلونه_ريال_مدريد',
#     'url': 'http://twitter.com/search?q=%23%D8%A8%D8%B1%D8%B4%D9%84%D9%88%D9%86%D9%87_%D8%B1%D9%8A%D8%A7%D9%84_%D9%85%D8%AF%D8%B1%D9%8A%D8%AF',
#     'promoted_content': None,
#     'query': '%23%D8%A8%D8%B1%D8%B4%D9%84%D9%88%D9%86%D9%87_%D8%B1%D9%8A%D8%A7%D9%84_%D9%85%D8%AF%D8%B1%D9%8A%D8%AF',
#     'tweet_volume': 48278},
#    {'name': '#RealMadridBarcelona',
#     'url': 'http://twitter.com/search?q=%23RealMadridBarcelona',
#     'promoted_content': None,
#     'query': '%23RealMadridBarcelona',
#     'tweet_volume': None},
#    {'name': 'Isco',
#     'url': 'http://twitter.com/search?q=Isco',
#     'promoted_content': None,
#     'query': 'Isco',
#     'tweet_volume': 17485},
#    {'name': 'Piqué',
#     'url': 'http://twitter.com/search?q=Piqu%C3%A9',
#     'promoted_content': None,
#     'query': 'Piqu%C3%A9',
#     'tweet_volume': 72265},
#    {'name': 'Lenglet',
#     'url': 'http://twitter.com/search?q=Lenglet',
#     'promoted_content': None,
#     'query': 'Lenglet',
#     'tweet_volume': 18748},
#    {'name': 'Arturo Vidal',
#     'url': 'http://twitter.com/search?q=%22Arturo+Vidal%22',
#     'promoted_content': None,
#     'query': '%22Arturo+Vidal%22',
#     'tweet_volume': None},
#    {'name': 'DK Metcalf',
#     'url': 'http://twitter.com/search?q=%22DK+Metcalf%22',
#     'promoted_content': None,
#     'query': '%22DK+Metcalf%22',
#     'tweet_volume': 15590},
#    {'name': 'Sergi Roberto',
#     'url': 'http://twitter.com/search?q=%22Sergi+Roberto%22',
#     'promoted_content': None,
#     'query': '%22Sergi+Roberto%22',
#     'tweet_volume': None},
#    {'name': 'Asensio',
#     'url': 'http://twitter.com/search?q=Asensio',
#     'promoted_content': None,
#     'query': 'Asensio',
#     'tweet_volume': None},
#    {'name': 'Modric',
#     'url': 'http://twitter.com/search?q=Modric',
#     'promoted_content': None,
#     'query': 'Modric',
#     'tweet_volume': 16499},
#    {'name': 'Courtois',
#     'url': 'http://twitter.com/search?q=Courtois',
#     'promoted_content': None,
#     'query': 'Courtois',
#     'tweet_volume': 11509},
#    {'name': 'Santiago Bernabéu',
#     'url': 'http://twitter.com/search?q=%22Santiago+Bernab%C3%A9u%22',
#     'promoted_content': None,
#     'query': '%22Santiago+Bernab%C3%A9u%22',
#     'tweet_volume': 27300},
#    {'name': 'Lukaku',
#     'url': 'http://twitter.com/search?q=Lukaku',
#     'promoted_content': None,
#     'query': 'Lukaku',
#     'tweet_volume': 112132},
#    {'name': 'Astralis',
#     'url': 'http://twitter.com/search?q=Astralis',
#     'promoted_content': None,
#     'query': 'Astralis',
#     'tweet_volume': 13026},
#    {'name': 'Busquets',
#     'url': 'http://twitter.com/search?q=Busquets',
#     'promoted_content': None,
#     'query': 'Busquets',
#     'tweet_volume': 10163},
#    {'name': 'Real Madrid 0-1 Barcelona',
#     'url': 'http://twitter.com/search?q=%22Real+Madrid+0-1+Barcelona%22',
#     'promoted_content': None,
#     'query': '%22Real+Madrid+0-1+Barcelona%22',
#     'tweet_volume': None},
#    {'name': 'Undiano',
#     'url': 'http://twitter.com/search?q=Undiano',
#     'promoted_content': None,
#     'query': 'Undiano',
#     'tweet_volume': None},
#    {'name': '#LazioRoma',
#     'url': 'http://twitter.com/search?q=%23LazioRoma',
#     'promoted_content': None,
#     'query': '%23LazioRoma',
#     'tweet_volume': 14419},
#    {'name': '#السعوديه_تاسع_اقوي_دول_العالم',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87_%D8%AA%D8%A7%D8%B3%D8%B9_%D8%A7%D9%82%D9%88%D9%8A_%D8%AF%D9%88%D9%84_%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87_%D8%AA%D8%A7%D8%B3%D8%B9_%D8%A7%D9%82%D9%88%D9%8A_%D8%AF%D9%88%D9%84_%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85',
#     'tweet_volume': 13743},
#    {'name': '#ForçaBarça',
#     'url': 'http://twitter.com/search?q=%23For%C3%A7aBar%C3%A7a',
#     'promoted_content': None,
#     'query': '%23For%C3%A7aBar%C3%A7a',
#     'tweet_volume': 34542},
#    {'name': '#StephonClark',
#     'url': 'http://twitter.com/search?q=%23StephonClark',
#     'promoted_content': None,
#     'query': '%23StephonClark',
#     'tweet_volume': None},
#    {'name': '#SomosMIBR',
#     'url': 'http://twitter.com/search?q=%23SomosMIBR',
#     'promoted_content': None,
#     'query': '%23SomosMIBR',
#     'tweet_volume': 11895},
#    {'name': '#EnKlasikYalanlar',
#     'url': 'http://twitter.com/search?q=%23EnKlasikYalanlar',
#     'promoted_content': None,
#     'query': '%23EnKlasikYalanlar',
#     'tweet_volume': None},
#    {'name': '#SamsunlularSesVersin',
#     'url': 'http://twitter.com/search?q=%23SamsunlularSesVersin',
#     'promoted_content': None,
#     'query': '%23SamsunlularSesVersin',
#     'tweet_volume': None},
#    {'name': '#RMAFCB',
#     'url': 'http://twitter.com/search?q=%23RMAFCB',
#     'promoted_content': None,
#     'query': '%23RMAFCB',
#     'tweet_volume': 10349},
#    {'name': '#insiders',
#     'url': 'http://twitter.com/search?q=%23insiders',
#     'promoted_content': None,
#     'query': '%23insiders',
#     'tweet_volume': None},
#    {'name': '#SAFTAs13',
#     'url': 'http://twitter.com/search?q=%23SAFTAs13',
#     'promoted_content': None,
#     'query': '%23SAFTAs13',
#     'tweet_volume': 27925},
#    {'name': '#ViscaBarça',
#     'url': 'http://twitter.com/search?q=%23ViscaBar%C3%A7a',
#     'promoted_content': None,
#     'query': '%23ViscaBar%C3%A7a',
#     'tweet_volume': None},
#    {'name': '#UltimateTommyBoyCHANYEOL',
#     'url': 'http://twitter.com/search?q=%23UltimateTommyBoyCHANYEOL',
#     'promoted_content': None,
#     'query': '%23UltimateTommyBoyCHANYEOL',
#     'tweet_volume': 169368},
#    {'name': '#nrkmgp',
#     'url': 'http://twitter.com/search?q=%23nrkmgp',
#     'promoted_content': None,
#     'query': '%23nrkmgp',
#     'tweet_volume': None},
#    {'name': '#12stig',
#     'url': 'http://twitter.com/search?q=%2312stig',
#     'promoted_content': None,
#     'query': '%2312stig',
#     'tweet_volume': None},
#    {'name': '#BugünGünlerdenGALATASARAY',
#     'url': 'http://twitter.com/search?q=%23Bug%C3%BCnG%C3%BCnlerdenGALATASARAY',
#     'promoted_content': None,
#     'query': '%23Bug%C3%BCnG%C3%BCnlerdenGALATASARAY',
#     'tweet_volume': None},
#    {'name': '#MüslümGürses',
#     'url': 'http://twitter.com/search?q=%23M%C3%BCsl%C3%BCmG%C3%BCrses',
#     'promoted_content': None,
#     'query': '%23M%C3%BCsl%C3%BCmG%C3%BCrses',
#     'tweet_volume': None},
#    {'name': '#oraomaipiù',
#     'url': 'http://twitter.com/search?q=%23oraomaipi%C3%B9',
#     'promoted_content': None,
#     'query': '%23oraomaipi%C3%B9',
#     'tweet_volume': None},
#    {'name': '#TheVoiceUK',
#     'url': 'http://twitter.com/search?q=%23TheVoiceUK',
#     'promoted_content': None,
#     'query': '%23TheVoiceUK',
#     'tweet_volume': None},
#    {'name': '#CasualtyXHolby',
#     'url': 'http://twitter.com/search?q=%23CasualtyXHolby',
#     'promoted_content': None,
#     'query': '%23CasualtyXHolby',
#     'tweet_volume': None},
#    {'name': '#AnketlerdeEytÇıktı',
#     'url': 'http://twitter.com/search?q=%23AnketlerdeEyt%C3%87%C4%B1kt%C4%B1',
#     'promoted_content': None,
#     'query': '%23AnketlerdeEyt%C3%87%C4%B1kt%C4%B1',
#     'tweet_volume': 165887},
#    {'name': '#RealxBarcanaESPN',
#     'url': 'http://twitter.com/search?q=%23RealxBarcanaESPN',
#     'promoted_content': None,
#     'query': '%23RealxBarcanaESPN',
#     'tweet_volume': None},
#    {'name': '#RatedLegendShow',
#     'url': 'http://twitter.com/search?q=%23RatedLegendShow',
#     'promoted_content': None,
#     'query': '%23RatedLegendShow',
#     'tweet_volume': None},
#    {'name': '#widm',
#     'url': 'http://twitter.com/search?q=%23widm',
#     'promoted_content': None,
#     'query': '%23widm',
#     'tweet_volume': None},
#    {'name': '#moltalk',
#     'url': 'http://twitter.com/search?q=%23moltalk',
#     'promoted_content': None,
#     'query': '%23moltalk',
#     'tweet_volume': None},
#    {'name': '#قسم_لن_نسافر_تركيا',
#     'url': 'http://twitter.com/search?q=%23%D9%82%D8%B3%D9%85_%D9%84%D9%86_%D9%86%D8%B3%D8%A7%D9%81%D8%B1_%D8%AA%D8%B1%D9%83%D9%8A%D8%A7',
#     'promoted_content': None,
#     'query': '%23%D9%82%D8%B3%D9%85_%D9%84%D9%86_%D9%86%D8%B3%D8%A7%D9%81%D8%B1_%D8%AA%D8%B1%D9%83%D9%8A%D8%A7',
#     'tweet_volume': 37147},
#    {'name': '#RMABAR',
#     'url': 'http://twitter.com/search?q=%23RMABAR',
#     'promoted_content': None,
#     'query': '%23RMABAR',
#     'tweet_volume': None},
#    {'name': '#FAQSbotifarraTV3',
#     'url': 'http://twitter.com/search?q=%23FAQSbotifarraTV3',
#     'promoted_content': None,
#     'query': '%23FAQSbotifarraTV3',
#     'tweet_volume': None},
#    {'name': '#FestivaldaCancao',
#     'url': 'http://twitter.com/search?q=%23FestivaldaCancao',
#     'promoted_content': None,
#     'query': '%23FestivaldaCancao',
#     'tweet_volume': None}],
#   'as_of': '2019-03-02T22:41:12Z',
#   'created_at': '2019-03-02T22:35:40Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#loveSTEMsd', 'url': 'http://twitter.com/search?q=%23loveSTEMsd', 'promoted_content': None, 'query': '%23loveSTEMsd', 'tweet_volume': None}, {'name': 'Jordyn', 'url': 'http://twitter.com/search?q=Jordyn', 'promoted_content': None, 'query': 'Jordyn', 'tweet_volume': 1204836}, {'name': 'CPAC', 'url': 'http://twitter.com/search?q=CPAC', 'promoted_content': None, 'query': 'CPAC', 'tweet_volume': 422694}, {'name': 'Khloe', 'url': 'http://twitter.com/search?q=Khloe', 'promoted_content': None, 'query': 'Khloe', 'tweet_volume': 858206}, {'name': 'Tristan', 'url': 'http://twitter.com/search?q=Tristan', 'promoted_content': None, 'query': 'Tristan', 'tweet_volume': 775297}, {'name': '#TwitterBestFandom', 'url': 'http://twitter.com/search?q=%23TwitterBestFandom', 'promoted_content': None, 'query': '%23TwitterBestFandom', 'tweet_volume': 19201091}, {'name': '#SoompiAwards', 'url': 'http://twitter.com/search?q=%23SoompiAwards', 'promoted_content': None, 'query': '%23SoompiAwards', 'tweet_volume': 17269895}, {'name': '#SaturdayMorning', 'url': 'http://twitter.com/search?q=%23SaturdayMorning', 'promoted_content': None, 'query': '%23SaturdayMorning', 'tweet_volume': 50775}, {'name': '#PWG200', 'url': 'http://twitter.com/search?q=%23PWG200', 'promoted_content': None, 'query': '%23PWG200', 'tweet_volume': None}, {'name': 'Jonas Brothers', 'url': 'http://twitter.com/search?q=%22Jonas+Brothers%22', 'promoted_content': None, 'query': '%22Jonas+Brothers%22', 'tweet_volume': 396625}, {'name': 'DK Metcalf', 'url': 'http://twitter.com/search?q=%22DK+Metcalf%22', 'promoted_content': None, 'query': '%22DK+Metcalf%22', 'tweet_volume': 15590}, {'name': 'Ramos', 'url': 'http://twitter.com/search?q=Ramos', 'promoted_content': None, 'query': 'Ramos', 'tweet_volume': 205015}, {'name': 'Jordan Bone', 'url': 'http://twitter.com/search?q=%22Jordan+Bone%22', 'promoted_content': None, 'query': '%22Jordan+Bone%22', 'tweet_volume': None}, {'name': 'Reid Travis', 'url': 'http://twitter.com/search?q=%22Reid+Travis%22', 'promoted_content': None, 'query': '%22Reid+Travis%22', 'tweet_volume': None}, {'name': 'Steve Smith', 'url': 'http://twitter.com/search?q=%22Steve+Smith%22', 'promoted_content': None, 'query': '%22Steve+Smith%22', 'tweet_volume': None}, {'name': 'Rakitic', 'url': 'http://twitter.com/search?q=Rakitic', 'promoted_content': None, 'query': 'Rakitic', 'tweet_volume': 54841}, {'name': 'Isco', 'url': 'http://twitter.com/search?q=Isco', 'promoted_content': None, 'query': 'Isco', 'tweet_volume': 17485}, {'name': 'Go Vols', 'url': 'http://twitter.com/search?q=%22Go+Vols%22', 'promoted_content': None, 'query': '%22Go+Vols%22', 'tweet_volume': None}, {'name': 'Senior Day', 'url': 'http://twitter.com/search?q=%22Senior+Day%22', 'promoted_content': None, 'query': '%22Senior+Day%22', 'tweet_volume': None}, {'name': 'Andy Isabella', 'url': 'http://twitter.com/search?q=%22Andy+Isabella%22', 'promoted_content': None, 'query': '%22Andy+Isabella%22', 'tweet_volume': None}, {'name': 'Vidal', 'url': 'http://twitter.com/search?q=Vidal', 'promoted_content': None, 'query': 'Vidal', 'tweet_volume': 36668}, {'name': 'Franch', 'url': 'http://twitter.com/search?q=Franch', 'promoted_content': None, 'query': 'Franch', 'tweet_volume': None}, {'name': 'Calvin Johnson', 'url': 'http://twitter.com/search?q=%22Calvin+Johnson%22', 'promoted_content': None, 'query': '%22Calvin+Johnson%22', 'tweet_volume': None}, {'name': 'Spielberg', 'url': 'http://twitter.com/search?q=Spielberg', 'promoted_content': None, 'query': 'Spielberg', 'tweet_volume': 27180}, {'name': 'Tacko Fall', 'url': 'http://twitter.com/search?q=%22Tacko+Fall%22', 'promoted_content': None, 'query': '%22Tacko+Fall%22', 'tweet_volume': None}, {'name': 'Solari', 'url': 'http://twitter.com/search?q=Solari', 'promoted_content': None, 'query': 'Solari', 'tweet_volume': 20208}, {'name': 'Julio Jones', 'url': 'http://twitter.com/search?q=%22Julio+Jones%22', 'promoted_content': None, 'query': '%22Julio+Jones%22', 'tweet_volu ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(local_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#CePostaPerTe",
#     "url": "http://twitter.com/search?q=%23CePostaPerTe",
#     "promoted_content": null,
#     "query": "%23CePostaPerTe",
#     "tweet_volume": 13093
#    },
#    {
#     "name": "#LazioRoma",
#     "url": "http://twitter.com/search?q=%23LazioRoma",
#     "promoted_content": null,
#     "query": "%23LazioRoma",
#     "tweet_volume": 13927
#    },
#    {
#     "name": "#oraomaipi\u00f9",
#     "url": "http://twitter.com/search?q=%23oraomaipi%C3%B9",
#     "promoted_content": null,
#     "query": "%23oraomaipi%C3%B9",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MilanSassuolo",
#     "url": "http://twitter.com/search?q=%23MilanSassuolo",
#     "promoted_content": null,
#     "query": "%23MilanSassuolo",
#     "tweet_volume": 15932
#    },
#    {
#     "name": "#primalepersone",
#     "url": "http://twitter.com/search?q=%23primalepersone",
#     "promoted_content": null,
#     "query": "%23primalepersone",
#     "tweet_volume": 43450
#    },
#    {
#     "name": "Domenico",
#     "url": "http://twitter.com/search?q=Domenico",
#     "promoted_content": null,
#     "query": "Domenico",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mim\u00ec",
#     "url": "http://twitter.com/search?q=Mim%C3%AC",
#     "promoted_content": null,
#     "query": "Mim%C3%AC",
#     "tweet_volume": 41272
#    },
#    {
#     "name": "Ornella Vanoni",
#     "url": "http://twitter.com/search?q=%22Ornella+Vanoni%22",
#     "promoted_content": null,
#     "query": "%22Ornella+Vanoni%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Di Francesco",
#     "url": "http://twitter.com/search?q=%22Di+Francesco%22",
#     "promoted_content": null,
#     "query": "%22Di+Francesco%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Minetti",
#     "url": "http://twitter.com/search?q=Minetti",
#     "promoted_content": null,
#     "query": "Minetti",
#     "tweet_volume": null
#    },
#    {
#     "name": "Milani",
#     "url": "http://twitter.com/search?q=Milani",
#     "promoted_content": null,
#     "query": "Milani",
#     "tweet_volume": null
#    },
#    {
#     "name": "La Lazio",
#     "url": "http://twitter.com/search?q=%22La+Lazio%22",
#     "promoted_content": null,
#     "query": "%22La+Lazio%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Gianni Bella",
#     "url": "http://twitter.com/search?q=%22Gianni+Bella%22",
#     "promoted_content": null,
#     "query": "%22Gianni+Bella%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Vallesi",
#     "url": "http://twitter.com/search?q=Vallesi",
#     "promoted_content": null,
#     "query": "Vallesi",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sergio Ramos",
#     "url": "http://twitter.com/search?q=%22Sergio+Ramos%22",
#     "promoted_content": null,
#     "query": "%22Sergio+Ramos%22",
#     "tweet_volume": 63665
#    },
#    {
#     "name": "Jessica Morlacchi",
#     "url": "http://twitter.com/search?q=%22Jessica+Morlacchi%22",
#     "promoted_content": null,
#     "query": "%22Jessica+Morlacchi%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Pastore",
#     "url": "http://twitter.com/search?q=Pastore",
#     "promoted_content": null,
#     "query": "Pastore",
#     "tweet_volume": null
#    },
#    {
#     "name": "De Marinis",
#     "url": "http://twitter.com/search?q=%22De+Marinis%22",
#     "promoted_content": null,
#     "query": "%22De+Marinis%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Marcella",
#     "url": "http://twitter.com/search?q=Marcella",
#     "promoted_content": null,
#     "query": "Marcella",
#     "tweet_volume": null
#    },
#    {
#     "name": "Orietta Berti",
#     "url": "http://twitter.com/search?q=%22Orietta+Berti%22",
#     "promoted_content": null,
#     "query": "%22Orietta+Berti%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Amadeus",
#     "url": "http://twitter.com/search?q=Amadeus",
#     "promoted_content": null,
#     "query": "Amadeus",
#     "tweet_volume": null
#    },
#    {
#     "name": "Red Canzian",
#     "url": "http://twitter.com/search?q=%22Red+Canzian%22",
#     "promoted_content": null,
#     "query": "%22Red+Canzian%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Florenzi",
#     "url": "http://twitter.com/search?q=Florenzi",
#     "promoted_content": null,
#     "query": "Florenzi",
#     "tweet_volume": null
#    },
#    {
#     "name": "Michele Pecora",
#     "url": "http://twitter.com/search?q=%22Michele+Pecora%22",
#     "promoted_content": null,
#     "query": "%22Michele+Pecora%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Salemi",
#     "url": "http://twitter.com/search?q=Salemi",
#     "promoted_content": null,
#     "query": "Salemi",
#     "tweet_volume": null
#    },
#    {
#     "name": "Manolas",
#     "url": "http://twitter.com/search?q=Manolas",
#     "promoted_content": null,
#     "query": "Manolas",
#     "tweet_volume": null
#    },
#    {
#     "name": "Cola",
#     "url": "http://twitter.com/search?q=Cola",
#     "promoted_content": null,
#     "query": "Cola",
#     "tweet_volume": 39664
#    },
#    {
#     "name": "Toto Cutugno",
#     "url": "http://twitter.com/search?q=%22Toto+Cutugno%22",
#     "promoted_content": null,
#     "query": "%22Toto+Cutugno%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Forza Roma",
#     "url": "http://twitter.com/search?q=%22Forza+Roma%22",
#     "promoted_content": null,
#     "query": "%22Forza+Roma%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Consigli",
#     "url": "http://twitter.com/search?q=Consigli",
#     "promoted_content": null,
#     "query": "Consigli",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TwitterBestFandom",
#     "url": "http://twitter.com/search?q=%23TwitterBestFandom",
#     "promoted_content": null,
#     "query": "%23TwitterBestFandom",
#     "tweet_volume": 19334508
#    },
#    {
#     "name": "#lascelta",
#     "url": "http://twitter.com/search?q=%23lascelta",
#     "promoted_content": null,
#     "query": "%23lascelta",
#     "tweet_volume": 17638
#    },
#    {
#     "name": "#allegri",
#     "url": "http://twitter.com/search?q=%23allegri",
#     "promoted_content": null,
#     "query": "%23allegri",
#     "tweet_volume": null
#    },
#    {
#     "name": "#people",
#     "url": "http://twitter.com/search?q=%23people",
#     "promoted_content": null,
#     "query": "%23people",
#     "tweet_volume": 14658
#    },
#    {
#     "name": "#Amici18",
#     "url": "http://twitter.com/search?q=%23Amici18",
#     "promoted_content": null,
#     "query": "%23Amici18",
#     "tweet_volume": 29807
#    },
#    {
#     "name": "#Cataldi",
#     "url": "http://twitter.com/search?q=%23Cataldi",
#     "promoted_content": null,
#     "query": "%23Cataldi",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Presadiretta",
#     "url": "http://twitter.com/search?q=%23Presadiretta",
#     "promoted_content": null,
#     "query": "%23Presadiretta",
#     "tweet_volume": null
#    },
#    {
#     "name": "#caicedo",
#     "url": "http://twitter.com/search?q=%23caicedo",
#     "promoted_content": null,
#     "query": "%23caicedo",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DerbyDellaCapitale",
#     "url": "http://twitter.com/search?q=%23DerbyDellaCapitale",
#     "promoted_content": null,
#     "query": "%23DerbyDellaCapitale",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DAZN",
#     "url": "http://twitter.com/search?q=%23DAZN",
#     "promoted_content": null,
#     "query": "%23DAZN",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Kolarov",
#     "url": "http://twitter.com/search?q=%23Kolarov",
#     "promoted_content": null,
#     "query": "%23Kolarov",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Immobile",
#     "url": "http://twitter.com/search?q=%23Immobile",
#     "promoted_content": null,
#     "query": "%23Immobile",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ElCl\u00e1sico",
#     "url": "http://twitter.com/search?q=%23ElCl%C3%A1sico",
#     "promoted_content": null,
#     "query": "%23ElCl%C3%A1sico",
#     "tweet_volume": 191629
#    },
#    {
#     "name": "#realbarca",
#     "url": "http://twitter.com/search?q=%23realbarca",
#     "promoted_content": null,
#     "query": "%23realbarca",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RealMadridBarcelona",
#     "url": "http://twitter.com/search?q=%23RealMadridBarcelona",
#     "promoted_content": null,
#     "query": "%23RealMadridBarcelona",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ForzaLazio",
#     "url": "http://twitter.com/search?q=%23ForzaLazio",
#     "promoted_content": null,
#     "query": "%23ForzaLazio",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Olsen",
#     "url": "http://twitter.com/search?q=%23Olsen",
#     "promoted_content": null,
#     "query": "%23Olsen",
#     "tweet_volume": null
#    },
#    {
#     "name": "#derbydiroma",
#     "url": "http://twitter.com/search?q=%23derbydiroma",
#     "promoted_content": null,
#     "query": "%23derbydiroma",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Inzaghi",
#     "url": "http://twitter.com/search?q=%23Inzaghi",
#     "promoted_content": null,
#     "query": "%23Inzaghi",
#     "tweet_volume": null
#    },
#    {
#     "name": "#UltimateTommyBoyCHANYEOL",
#     "url": "http://twitter.com/search?q=%23UltimateTommyBoyCHANYEOL",
#     "promoted_content": null,
#     "query": "%23UltimateTommyBoyCHANYEOL",
#     "tweet_volume": 161166
#    }
#   ],
#   "as_of": "2019-03-02T22:26:23Z",
#   "created_at": "2019-03-02T22:20:41Z",
#   "locations": [
#    {
#     "name": "Turin",
#     "woeid": 725003
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']]) 

trends_set
# Out:
# {'world': {'#12stig',
#   '#AnketlerdeEytÇıktı',
#   '#BugünGünlerdenGALATASARAY',
#   '#CasualtyXHolby',
#   '#CePostaPerTe',
#   '#ElClasico',
#   '#EnKlasikYalanlar',
#   '#FestivaldaCancao',
#   '#ForçaBarça',
#   '#LaLigaxESPN',
#   '#LazioRoma',
#   '#MUNSOU',
#   '#MüslümGürses',
#   '#RMABAR',
#   '#RMAFCB',
#   '#RealMadridBarcelona',
#   '#RealxBarcanaESPN',
#   '#SAFTAs13',
#   '#SamsunlularSesVersin',
#   '#SomosMIBR',
#   '#StephonClark',
#   '#TeamBTS',
#   '#TheVoiceUK',
#   '#UltimateTommyBoyCHANYEOL',
#   '#ViscaBarça',
#   '#moltalk',
#   '#nrkmgp',
#   '#oraomaipiù',
#   '#widm',
#   '#السعوديه_تاسع_اقوي_دول_العالم',
#   '#برشلونه_ريال_مدريد',
#   '#قسم_لن_نسافر_تركيا',
#   'Arturo Vidal',
#   'Asensio',
#   'Astralis',
#   'Busquets',
#   'Courtois',
#   'DK Metcalf',
#   'Huesca',
#   'Isco',
#   'Kroos',
#   'Lenglet',
#   'Lukaku',
#   'Modric',
#   'Pique',
#   'Rakitic',
#   'Ramos',
#   'Real Madrid 0-1 Barcelona',
#   'Sergi Roberto',
#   'Undiano'},
#  'us': {'#BernieInBrooklyn',
#   '#BoydGaming300',
#   '#CLBvRBNY',
#   '#CPAC19',
#   '#Caturday',
#   '#ElClasico',
#   '#ForçaBarça',
#   '#GoVols',
#   '#MLSisBack',
#   '#MySpaceshipCan',
#   '#NFLCombine19',
#   '#NYCFC',
#   '#ORLvNYC',
#   '#OhMyDad',
#   '#PHIvTOR',
#   '#SoompiAwards',
#   '#StephonClark',
#   '#TeamBTS',
#   '#TexasIndependenceDay',
#   '#TommyXZendaya',
#   '#TwitterBestFandom',
#   '#UKvsTENN',
#   '#UKvsUT',
#   '#USAvENG',
#   '#popcornopolis',
#   '#viscabarça',
#   'Admiral',
#   "Alex O'Connell",
#   'Andy Isabella',
#   'Bernabeu',
#   'Calvin Johnson',
#   'DK Metcalf',
#   'Franch',
#   'Go Vols',
#   'Hagans',
#   'Isco',
#   'Jordan Bone',
#   'Julio Jones',
#   'Lenglet',
#   'Rakitic',
#   'Ramos',
#   'Reid Travis',
#   'Senior Day',
#   'Solari',
#   'Spielberg',
#   'Steve Smith',
#   'Tepig',
#   'Vidal',
#   'Visca Barca',
#   'nick richards'},
#  'san diego': {'#Amici18',
#   '#Cataldi',
#   '#CePostaPerTe',
#   '#DAZN',
#   '#DerbyDellaCapitale',
#   '#ElClásico',
#   '#ForzaLazio',
#   '#Immobile',
#   '#Inzaghi',
#   '#Kolarov',
#   '#LazioRoma',
#   '#MilanSassuolo',
#   '#Olsen',
#   '#Presadiretta',
#   '#RealMadridBarcelona',
#   '#TwitterBestFandom',
#   '#UltimateTommyBoyCHANYEOL',
#   '#allegri',
#   '#caicedo',
#   '#derbydiroma',
#   '#lascelta',
#   '#oraomaipiù',
#   '#people',
#   '#primalepersone',
#   '#realbarca',
#   'Amadeus',
#   'Cola',
#   'Consigli',
#   'De Marinis',
#   'Di Francesco',
#   'Domenico',
#   'Florenzi',
#   'Forza Roma',
#   'Gianni Bella',
#   'Jessica Morlacchi',
#   'La Lazio',
#   'Manolas',
#   'Marcella',
#   'Michele Pecora',
#   'Milani',
#   'Mimì',
#   'Minetti',
#   'Orietta Berti',
#   'Ornella Vanoni',
#   'Pastore',
#   'Red Canzian',
#   'Salemi',
#   'Sergio Ramos',
#   'Toto Cutugno',
#   'Vallesi'}}

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #CasualtyXHolby,Asensio,Rakitic,Lukaku,Isco,Huesca,#BugünGünlerdenGALATASARAY,Astralis,#AnketlerdeEytÇıktı,#LazioRoma,Lenglet,#برشلونه_ريال_مدريد,Busquets,#RMAFCB,#FestivaldaCancao,Pique,#قسم_لن_نسافر_تركيا,#widm,#StephonClark,Ramos,#nrkmgp,#RealxBarcanaESPN,#oraomaipiù,#12stig,#MUNSOU,Courtois,#CePostaPerTe,#ViscaBarça,Arturo Vidal,#UltimateTommyBoyCHANYEOL,#SomosMIBR,#TeamBTS,Real Madrid 0-1 Barcelona,#السعوديه_تاسع_اقوي_دول_العالم,DK Metcalf,#ElClasico,#MüslümGürses,Kroos,#SamsunlularSesVersin,#TheVoiceUK,Modric,#SAFTAs13,#LaLigaxESPN,#RMABAR,#RealMadridBarcelona,Sergi Roberto,#EnKlasikYalanlar,#moltalk,Undiano,#ForçaBarça
# ('----------', 'us')
# Alex O'Connell,#ORLvNYC,#USAvENG,Spielberg,Rakitic,#MySpaceshipCan,Vidal,#BoydGaming300,#popcornopolis,Isco,Solari,#GoVols,Senior Day,Jordan Bone,Lenglet,Go Vols,nick richards,Steve Smith,#UKvsUT,Andy Isabella,Reid Travis,#StephonClark,Visca Barca,Ramos,Bernabeu,#MLSisBack,#SoompiAwards,Julio Jones,Calvin Johnson,#NYCFC,Franch,#TexasIndependenceDay,#UKvsTENN,#BernieInBrooklyn,#TommyXZendaya,Tepig,#CPAC19,#TeamBTS,DK Metcalf,#ElClasico,#OhMyDad,#CLBvRBNY,Admiral,#NFLCombine19,Hagans,#PHIvTOR,#TwitterBestFandom,#Caturday,#viscabarça,#ForçaBarça
# ('----------', 'san diego')
# #Amici18,#caicedo,De Marinis,Consigli,#derbydiroma,Salemi,Milani,Minetti,Forza Roma,#lascelta,Florenzi,La Lazio,#LazioRoma,Ornella Vanoni,Manolas,Vallesi,Michele Pecora,#Cataldi,#Presadiretta,#realbarca,Domenico,Amadeus,Pastore,Gianni Bella,#primalepersone,#Olsen,#oraomaipiù,#Kolarov,Sergio Ramos,Red Canzian,Di Francesco,#people,#CePostaPerTe,Jessica Morlacchi,#UltimateTommyBoyCHANYEOL,Orietta Berti,#allegri,#MilanSassuolo,#DAZN,#Inzaghi,Cola,Toto Cutugno,Mimì,#ForzaLazio,#DerbyDellaCapitale,#TwitterBestFandom,#ElClásico,#RealMadridBarcelona,#Immobile,Marcella

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'Lenglet', 'Rakitic', '#ElClasico', 'Isco', '#TeamBTS', '#StephonClark', 'DK Metcalf', 'Ramos', '#ForçaBarça'}
# ('==========', 'intersection of us and san-diego')
# {'#TwitterBestFandom'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#MTVAwards' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)

# %%
[s['text'] for s in search_results['statuses']]

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
